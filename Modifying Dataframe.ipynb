# %%
import pandas as pd

# %%
df = pd.DataFrame (
    [
        [1, '3 inc screw', 0.5, 0.75],
        [2, '2 inch nail', 0.10, 0.25],
        [3, 'hammer', 3.00, 5.50],
        [4, 'screwdriver', 2.50, 3.00]
    ],
    columns = ['Product ID', 'Description', 'Cost to Manufacture', 'Price']
)

# %%
df
# Out:
#    Product ID  Description  Cost to Manufacture  Price
# 0           1  3 inc screw                  0.5   0.75
# 1           2  2 inch nail                  0.1   0.25
# 2           3       hammer                  3.0   5.50
# 3           4  screwdriver                  2.5   3.00

# %%
-- Adding a Column I

# %%
df['Sold in Bulk?'] = ['Yes','Yes','No','No']

# %%
df
# Out:
#    Product ID  Description  Cost to Manufacture  Price Sold in Bulk?
# 0           1  3 inc screw                  0.5   0.75           Yes
# 1           2  2 inch nail                  0.1   0.25           Yes
# 2           3       hammer                  3.0   5.50            No
# 3           4  screwdriver                  2.5   3.00            No

# %%
-- Adding a Column II (1 kolom semua data sama)

# %%
df['Is taxed?'] = 'Yes'

# %%
df
# Out:
#    Product ID  Description  Cost to Manufacture  Price Sold in Bulk? Is taxed?
# 0           1  3 inc screw                  0.5   0.75           Yes       Yes
# 1           2  2 inch nail                  0.1   0.25           Yes       Yes
# 2           3       hammer                  3.0   5.50            No       Yes
# 3           4  screwdriver                  2.5   3.00            No       Yes

# %%
-- Adding a Column III (record diperoleh dari data record yang sudah ada)

# %%
df['Margin'] = df['Price'] - df['Cost to Manufacture']

# %%
df
# Out:
#    Product ID  Description  Cost to Manufacture  Price Sold in Bulk?  \
# 0           1  3 inc screw                  0.5   0.75           Yes
# 1           2  2 inch nail                  0.1   0.25           Yes
# 2           3       hammer                  3.0   5.50            No
# 3           4  screwdriver                  2.5   3.00            No
#
#   Is taxed?  Margin
# 0       Yes    0.25
# 1       Yes    0.15
# 2       Yes    2.50
# 3       Yes    0.50

# %%
-- Reviewing Lambda Function

# %%
mylambda = lambda str: str[0] + str[5]

# %%
(mylambda('This is a string'))
# Out:
# 'Ti'

# %%
Reviewing Lambda Function: If Statements

# %%
mylambda = lambda age: 'Welcome to BattleCity!' if age >= 13 else 'You must be over 13'

# %%
(mylambda (15))
# Out:
# 'Welcome to BattleCity!'

# %%
df = pd.read_csv ('project_inventory.csv')

# %%
df
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
-- Applying a Lambda to a Column

# %%
get_last_name = lambda str: str.split()[-1]

# %%
df['last_name'] = df.location.apply(get_last_name)

# %%
df['last_name']
# Out:
# 0       Island
# 1       Island
# 2       Island
# 3       Island
# 4       Island
# 5       Island
# 6       Island
# 7       Island
# 8       Island
# 9       Island
# 10    Brooklyn
# 11    Brooklyn
# 12    Brooklyn
# 13    Brooklyn
# 14    Brooklyn
# 15    Brooklyn
# 16    Brooklyn
# 17    Brooklyn
# 18    Brooklyn
# 19    Brooklyn
# 20      Queens
# 21      Queens
# 22      Queens
# 23      Queens
# 24      Queens
# 25      Queens
# 26      Queens
# 27      Queens
# 28      Queens
# Name: last_name, dtype: object

# %%
-- Applying a Lambda to a Row 
(axis = 1) diaplikasikan disetiap baris
(axis = 1) diaplikasikan dalam satu kolom

# %%
total_earned = lambda row: row['hours_worked'] *  row['hourly_wage'] if row['hours_worked'] <= 40 else (40 * row['hourly_wage']) + (row['hours_worked'] - 40) * (row['hourly_wage'] * 1.50)

df['total_earned'] = df.apply(total_earned, axis=1)

# %%
-- Renaming Columns

# %%
df = pd.read_csv ('project_inventory.csv')

# %%
df
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
df.columns = ['location','type','description','quantity','price']

# %%
df
# Out:
#            lokasi          type                 description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
- Renaming Columns II

# %%
df.rename(columns={
  'location':'lokasi'
}, inplace=True)

# %%
df
# Out:
#            lokasi          type                 description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
-- teraplay dalam 1 kolom

# %%
x = lambda x: 'animal' if x == 'leather'else 'vegan'

# %%
orders['shoe_source'] = orders.shoe_material.apply (x)

# %%
- teraplay untuk setiap baris

# %%
coba = lambda row: 'Dear Mr. ' + row['last_name'] if row['gender'] == 'male' else 'Dear Ms. ' + row['last_name']

# %%
orders['salutation'] = orders.apply(coba, axis = 1)
